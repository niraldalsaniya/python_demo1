# %%
#LOGIC BOX
while True:
  print("welcome to the logic box.what is your requirement ?")
  print("select your requirement\n1->Generate pattern\n2->analysis of enter the number\n3->Exit")
  logic_box = int(input("choose your requirement number:"))
  match logic_box:
      case 1:
          row_number = int(input("enter the number of rows:"))
          for i in range(1,row_number+1):
              for j in range(i):
                  print("$",end=" ")
                
              print()   
      case 2:
          num1 = int(input("enter starting range of number:"))
          num2 = int(input("enter ending range of number:"))
          addition = 0
          for k in range(num1,num2+1):
              if k < 0:
                  pass
              if k % 2 == 0:
                  print(f"{k} is a even number")
              else:
                  print(f"{k} is a odd number")
              addition += k
        
        
          print(f"your starting number {num1} to ending number {num2} addition all number:{addition}" )
        
      case 3:
          print("exit this project.goodbye!")
          break
# Out:
# welcome to the logic box.what is your requirement ?
# select your requirement
# 1->Generate pattern
# 2->analysis of enter the number
# 3->Exit
# choose your requirement number: 1
# enter the number of rows: 4
# $
# $ $
# $ $ $
# $ $ $ $
# welcome to the logic box.what is your requirement ?
# select your requirement
# 1->Generate pattern
# 2->analysis of enter the number
# 3->Exit
# choose your requirement number: 2
# enter starting range of number: 15
# enter ending range of number: 20
# 15 is a odd number
# 16 is a even number
# 17 is a odd number
# 18 is a even number
# 19 is a odd number
# 20 is a even number
# your starting number 15 to ending number 20 addition all number:105
# welcome to the logic box.what is your requirement ?
# select your requirement
# 1->Generate pattern
# 2->analysis of enter the number
# 3->Exit
# choose your requirement number: 3
# exit this project.goodbye!
